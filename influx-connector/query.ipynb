# %%
from influxdb_client import InfluxDBClient

token = "FAJAw3GAnDDEJe7inzqEfBOPSDE6CimObKf0stTW6B6aEuv05NZw5bSE0QgJZQmpGUC_7b16v4QLcLIJR41mKw=="
org = "polito"
client = InfluxDBClient(url="http://localhost:8086", token=token, org=org, debug=False)
bucket = "iot"
start_time = ""
stop_time = ""
cpu_list = ['cpu0', 'cpu1', 'cpu2', 'cpu3']

query = f'from(bucket: "{bucket}") \
            |> range(start: v.timeRangeStart, stop: v.timeRangeStop) \
            |> filter(fn: (r) => r["_measurement"] == "PC") \
            |> filter(fn: (r) => r["sensor_name"] in {cpu_list}) \
            |> filter(fn: (r) => r["_field"] == "value")'

# query_api = client.query_api()
# result = query_api.query_data_frame(query=str(query))

# df = result[['_time', '_measurement', '_field', '_value']]

# %%
query

# %%
from influxdb_client import InfluxDBClient

token = "FAJAw3GAnDDEJe7inzqEfBOPSDE6CimObKf0stTW6B6aEuv05NZw5bSE0QgJZQmpGUC_7b16v4QLcLIJR41mKw=="
org = "polito"
client = InfluxDBClient(url="http://localhost:8086", token=token, org=org, debug=False)
bucket = "iot"
start_time = ""
stop_time = ""
cpu_list = ['cpu0', 'cpu1', 'cpu2', 'cpu3']

# 将cpu_list转换为Flux查询中所需的格式
cpu_list_str = ', '.join([f'"{cpu}"' for cpu in cpu_list])

query = f'from(bucket: "{bucket}") \
            |> range(start: v.timeRangeStart, stop: v.timeRangeStop) \
            |> filter(fn: (r) => r["_measurement"] == "PC") \
            |> filter(fn: (r) => r["sensor_name"] in [{cpu_list_str}]) \
            |> filter(fn: (r) => r["_field"] == "value")'

query_api = client.query_api()
result = query_api.query_data_frame(query=str(query))

# %%
query

# %%
import pytz
import warnings
from influxdb_client import InfluxDBClient
from influxdb_client.client.warnings import MissingPivotFunction

warnings.simplefilter("ignore", MissingPivotFunction)

token = "FAJAw3GAnDDEJe7inzqEfBOPSDE6CimObKf0stTW6B6aEuv05NZw5bSE0QgJZQmpGUC_7b16v4QLcLIJR41mKw=="
org = "polito"
client = InfluxDBClient(url="http://localhost:8086", token=token, org=org, debug=False)
bucket = "iot"
start_time = "2023-11-07T15:30:00.000000Z"
stop_time = "2023-11-07T15:40:00.000000Z"
cpu_list = ['cpu0', 'cpu1', 'cpu2', 'cpu3', 'cpu4']
query_field = "value"
filter_expression = ' or '.join([f'r["sensor_name"] == "{sensor}"' for sensor in cpu_list])

# query time date must be UTC to match InfluDB default timezone.
query = f'from(bucket: "{bucket}") \
                  |> range(start: {start_time}, stop: {stop_time}) \
                  |> filter(fn: (r) => {filter_expression}) \
                  |> filter(fn: (r) => r["_field"] == "{query_field}")'

query_api = client.query_api()
result = query_api.query_data_frame(query=str(query))
# df = result[['_time', '_value', '_measurement', 'sensor_name', 'use_case']]

# def convert_to_rome_time(row):
#         dt = row['_time']
#         rome_tz = pytz.timezone('Europe/Rome')
#         rome_time = dt.astimezone(rome_tz)
#         row['_time'] = rome_time
#         return row

# df = df.apply(convert_to_rome_time, axis=1)

# %%
result
# Out:
#       result  table                    _start                     _stop  \
# 0    _result      0 2023-11-07 15:30:00+00:00 2023-11-07 15:40:00+00:00
# 1    _result      0 2023-11-07 15:30:00+00:00 2023-11-07 15:40:00+00:00
# 2    _result      0 2023-11-07 15:30:00+00:00 2023-11-07 15:40:00+00:00
# 3    _result      0 2023-11-07 15:30:00+00:00 2023-11-07 15:40:00+00:00
# 4    _result      0 2023-11-07 15:30:00+00:00 2023-11-07 15:40:00+00:00
# ..       ...    ...                       ...                       ...
# 495  _result      4 2023-11-07 15:30:00+00:00 2023-11-07 15:40:00+00:00
# 496  _result      4 2023-11-07 15:30:00+00:00 2023-11-07 15:40:00+00:00
# 497  _result      4 2023-11-07 15:30:00+00:00 2023-11-07 15:40:00+00:00
# 498  _result      4 2023-11-07 15:30:00+00:00 2023-11-07 15:40:00+00:00
# 499  _result      4 2023-11-07 15:30:00+00:00 2023-11-07 15:40:00+00:00
#
#                                _time  _value _field _measurement sensor_name
# 0   2023-11-07 15:30:03.431335+00:00     1.5  value           PC        cpu0
# 1   2023-11-07 15:30:09.432523+00:00     0.0  value           PC        cpu0
# 2   2023-11-07 15:30:15.433960+00:00     0.0  value           PC        cpu0
# 3   2023-11-07 15:30:21.435530+00:00     0.0  value           PC        cpu0
# 4   2023-11-07 15:30:27.437114+00:00     0.0  value           PC        cpu0
# ..                               ...     ...    ...          ...         ...
# 495 2023-11-07 15:39:33.578915+00:00     0.0  value           PC        cpu4
# 496 2023-11-07 15:39:39.578569+00:00     0.0  value           PC        cpu4
# 497 2023-11-07 15:39:45.635645+00:00     0.0  value           PC        cpu4
# 498 2023-11-07 15:39:51.585145+00:00     0.0  value           PC        cpu4
# 499 2023-11-07 15:39:57.589394+00:00     0.0  value           PC        cpu4
#
# [500 rows x 9 columns]

# %%
df = result[['_time', '_value', '_measurement', 'sensor_name', 'use_case']]

# %%
df
# Out:
#                                 _time  _value _measurement sensor_name  \
# 0    2023-11-07 14:00:02.298914+00:00     0.0           PC        cpu0
# 1    2023-11-07 14:00:08.297433+00:00     0.0           PC        cpu0
# 2    2023-11-07 14:00:14.300047+00:00     1.6           PC        cpu0
# 3    2023-11-07 14:00:20.309470+00:00     0.0           PC        cpu0
# 4    2023-11-07 14:00:26.305296+00:00     0.0           PC        cpu0
# ...                               ...     ...          ...         ...
# 1507 2023-11-07 14:49:57.321030+00:00     0.0           PC        cpu2
# 1508 2023-11-07 14:50:03.322282+00:00     7.8           PC        cpu2
# 1509 2023-11-07 14:50:09.321667+00:00     0.0           PC        cpu2
# 1510 2023-11-07 14:50:15.323226+00:00     0.0           PC        cpu2
# 1511 2023-11-07 14:50:21.324573+00:00     0.0           PC        cpu2
#
#        use_case
# 0     use_case1
# 1     use_case1
# 2     use_case1
# 3     use_case1
# 4     use_case1
# ...         ...
# 1507  use_case1
# 1508  use_case1
# 1509  use_case1
# 1510  use_case1
# 1511  use_case1
#
# [1512 rows x 5 columns]

# %%
import pytz
def convert_to_rome_time(row):
        dt = row['_time']
        rome_tz = pytz.timezone('Europe/Rome')
        rome_time = dt.astimezone(rome_tz)
        row['_time'] = rome_time
        return row

df = df.apply(convert_to_rome_time, axis=1)

# %%
df
# Out:
#                                 _time  _value _measurement sensor_name  \
# 0    2023-11-07 15:00:02.298914+01:00     0.0           PC        cpu0
# 1    2023-11-07 15:00:08.297433+01:00     0.0           PC        cpu0
# 2    2023-11-07 15:00:14.300047+01:00     1.6           PC        cpu0
# 3    2023-11-07 15:00:20.309470+01:00     0.0           PC        cpu0
# 4    2023-11-07 15:00:26.305296+01:00     0.0           PC        cpu0
# ...                               ...     ...          ...         ...
# 1507 2023-11-07 15:49:57.321030+01:00     0.0           PC        cpu2
# 1508 2023-11-07 15:50:03.322282+01:00     7.8           PC        cpu2
# 1509 2023-11-07 15:50:09.321667+01:00     0.0           PC        cpu2
# 1510 2023-11-07 15:50:15.323226+01:00     0.0           PC        cpu2
# 1511 2023-11-07 15:50:21.324573+01:00     0.0           PC        cpu2
#
#        use_case
# 0     use_case1
# 1     use_case1
# 2     use_case1
# 3     use_case1
# 4     use_case1
# ...         ...
# 1507  use_case1
# 1508  use_case1
# 1509  use_case1
# 1510  use_case1
# 1511  use_case1
#
# [1512 rows x 5 columns]

# %%
sensor_list = ['cpu0', 'cpu1', 'cpu2']

# 生成一个过滤条件字符串，根据传感器列表构建过滤条件
filter_expression = ' or '.join([f'r["sensor_name"] == "{sensor}"' for sensor in sensor_list])

# 构建完整的 Flux 查询
query = f'''
    from(bucket: "{bucket}")
        |> range(start: v.timeRangeStart, stop: v.timeRangeStop)
        |> filter(fn: (r) => r["_measurement"] == "PC")
        |> filter(fn: (r) => r["_field"] == "value")
        |> filter(fn: (r) => {filter_expression})
'''

# 在查询中包括生成的过滤条件

# %%
query
# Out:
# '\n    from(bucket: "iot")\n        |> range(start: v.timeRangeStart, stop: v.timeRangeStop)\n        |> filter(fn: (r) => r["_measurement"] == "PC")\n        |> filter(fn: (r) => r["_field"] == "value")\n        |> filter(fn: (r) => r["sensor_name"] == "cpu0" or r["sensor_name"] == "cpu1" or r["sensor_name"] == "cpu2")\n'

# %%
filter_expression
# Out:
# 'r["sensor_name"] == "cpu0" or r["sensor_name"] == "cpu1" or r["sensor_name"] == "cpu2"'

# %%
import os

# 相对路径
relative_path = 'net1.py'

# 获取相对路径的绝对路径
absolute_path = os.path.abspath(relative_path)

print("相对路径:", relative_path)
print("绝对路径:", absolute_path)
# Out:
# 相对路径: net1.py
# 绝对路径: c:\Users\39349\Documents\GitHub\DeviceHive-Yingjun\influx-connector\net1.py

# %%
'''
export csv
'''
import requests
import pandas as pd

query_params = {
    "query_type": "useCase1",
    "sensor_ids": ["cpu0", "cpu1"],
    "start_time": "2023-11-08T11:00:00.000000Z",
    "stop_time": "2023-11-08T13:00:00.000000Z"
}

response = requests.post("http://localhost:8000/csv/", json=query_params)

if response.status_code == 200:
    print("status 200")
#     json_data = response.json()
#     df = pd.read_json(json_data)
# else:
#     print(f"响应状态码: {response.status_code}")
#     print("CSV 文件生成失败。")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\39349\Documents\GitHub\DeviceHive-Yingjun\influx-connector\query.ipynb Cell 15 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/39349/Documents/GitHub/DeviceHive-Yingjun/influx-connector/query.ipynb#X20sZmlsZQ%3D%3D?line=15'>16</a> if response.status_code == 200:
#      <a href='vscode-notebook-cell:/c%3A/Users/39349/Documents/GitHub/DeviceHive-Yingjun/influx-connector/query.ipynb#X20sZmlsZQ%3D%3D?line=16'>17</a>     json_data = response.json()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/39349/Documents/GitHub/DeviceHive-Yingjun/influx-connector/query.ipynb#X20sZmlsZQ%3D%3D?line=17'>18</a>     df = pd.read_json(json_data)
#      <a href='vscode-notebook-cell:/c%3A/Users/39349/Documents/GitHub/DeviceHive-Yingjun/influx-connector/query.ipynb#X20sZmlsZQ%3D%3D?line=18'>19</a> else:
#      <a href='vscode-notebook-cell:/c%3A/Users/39349/Documents/GitHub/DeviceHive-Yingjun/influx-connector/query.ipynb#X20sZmlsZQ%3D%3D?line=19'>20</a>     print(f"响应状态码: {response.status_code}")
#
# File c:\Users\39349\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\json\_json.py:760, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     757 if convert_axes is None and orient != "table":
#     758     convert_axes = True
# --> 760 json_reader = JsonReader(
#     761     path_or_buf,
#     762     orient=orient,
#     763     typ=typ,
#     764     dtype=dtype,
#     765     convert_axes=convert_axes,
#     766     convert_dates=convert_dates,
#     767     keep_default_dates=keep_default_dates,
#     768     precise_float=precise_float,
#     769     date_unit=date_unit,
#     770     encoding=encoding,
#     771     lines=lines,
#     772     chunksize=chunksize,
#     773     compression=compression,
#     774     nrows=nrows,
#     775     storage_options=storage_options,
#     776     encoding_errors=encoding_errors,
#     777     dtype_backend=dtype_backend,
#     778     engine=engine,
#     779 )
#     781 if chunksize:
#     782     return json_reader
#
# File c:\Users\39349\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\json\_json.py:861, in JsonReader.__init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors, dtype_backend, engine)
#     859     self.data = filepath_or_buffer
#     860 elif self.engine == "ujson":
# --> 861     data = self._get_data_from_filepath(filepath_or_buffer)
#     862     self.data = self._preprocess_data(data)
#
# File c:\Users\39349\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\json\_json.py:901, in JsonReader._get_data_from_filepath(self, filepath_or_buffer)
#     894 filepath_or_buffer = stringify_path(filepath_or_buffer)
#     895 if (
#     896     not isinstance(filepath_or_buffer, str)
#     897     or is_url(filepath_or_buffer)
#     898     or is_fsspec_url(filepath_or_buffer)
#     899     or file_exists(filepath_or_buffer)
#     900 ):
# --> 901     self.handles = get_handle(
#     902         filepath_or_buffer,
#     903         "r",
#     904         encoding=self.encoding,
#     905         compression=self.compression,
#     906         storage_options=self.storage_options,
#     907         errors=self.encoding_errors,
#     908     )
#     909     filepath_or_buffer = self.handles.handle
#     910 elif (
#     911     isinstance(filepath_or_buffer, str)
#     912     and filepath_or_buffer.lower().endswith(
#    (...)
#     915     and not file_exists(filepath_or_buffer)
#     916 ):
#
# File c:\Users\39349\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:716, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     713     codecs.lookup_error(errors)
#     715 # open URLs
# --> 716 ioargs = _get_filepath_or_buffer(
#     717     path_or_buf,
#     718     encoding=encoding,
#     719     compression=compression,
#     720     mode=mode,
#     721     storage_options=storage_options,
#     722 )
#     724 handle = ioargs.filepath_or_buffer
#     725 handles: list[BaseBuffer]
#
# File c:\Users\39349\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:456, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     452 if not (
#     453     hasattr(filepath_or_buffer, "read") or hasattr(filepath_or_buffer, "write")
#     454 ):
#     455     msg = f"Invalid file path or buffer object type: {type(filepath_or_buffer)}"
# --> 456     raise ValueError(msg)
#     458 return IOArgs(
#     459     filepath_or_buffer=filepath_or_buffer,
#     460     encoding=encoding,
#    (...)
#     463     mode=mode,
#     464 )
#
# ValueError: Invalid file path or buffer object type: <class 'dict'>

# %%
df
# Out:
#                        _time  _value _measurement sensor_name
# 0    2023-11-07 21:30:05.308     0.0           PC        cpu0
# 1    2023-11-07 21:30:11.310     0.0           PC        cpu0
# 2    2023-11-07 21:30:17.311     0.0           PC        cpu0
# 3    2023-11-07 21:30:23.312     4.6           PC        cpu0
# 4    2023-11-07 21:30:29.316     0.0           PC        cpu0
# ...                      ...     ...          ...         ...
# 1159 2023-11-07 22:27:48.440     0.0           PC        cpu1
# 1160 2023-11-07 22:27:54.442     0.0           PC        cpu1
# 1161 2023-11-07 22:28:00.445     8.7           PC        cpu1
# 1162 2023-11-07 22:28:06.444     0.0           PC        cpu1
# 1163 2023-11-07 22:28:12.444    32.8           PC        cpu1
#
# [1164 rows x 4 columns]

# %%
if response.status_code == 200:
    print("CSV 文件生成成功！")
else:
    print(f"响应状态码: {response.status_code}")
    print("CSV 文件生成失败。")
    print("错误信息:")
    print(response.text)
# Out:
# 响应状态码: 500
# CSV 文件生成失败。
# 错误信息:
# {"detail":"Error: The file 'influxdb_config.json.json' does not exist."}

# %%
import os
current_directory = os.getcwd()
current_directory
subdirectory = "imsub"
final_directory = os.path.join(current_directory, subdirectory)

# %%
final_directory
# Out:
# 'c:\\Users\\39349\\Documents\\GitHub\\DeviceHive-Yingjun\\influx-connector\\imsub'

# %%
print(os.path.join("solutions", "solver9.csv"))
# Out:
# solutions\solver9.csv

# %%
import uuid
unique_id = uuid.uuid4()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\39349\Documents\GitHub\DeviceHive-Yingjun\influx-connector\query.ipynb Cell 24 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/39349/Documents/GitHub/DeviceHive-Yingjun/influx-connector/query.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> unique_id = uuid.uuid4()
#
# NameError: name 'uuid' is not defined
